# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.politifact.com/factchecks/'
result=requests.get(url)
content=result.text
soup=BeautifulSoup(content,'html.parser')
print(soup.prettify())

# result.status_code
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Fact-checks | PolitiFact
#   </title>
#   <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="description">
#    <meta content="all" name="robots">
#     <meta content="PolitiFact" name="publisher"/>
#     <meta content="PolitiFact" name="twitter:username">
#      <meta content="summary" name="twitter:card">
#       <meta content="PolitiFact" name="twitter:site"/>
#       <meta content="" name="twitter:url">
#        <meta content="" name="twitter:title"/>
#        <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="twitter:description"/>
# ...

# %%
data = soup.find_all('li',class_ = 'o-listicle__item')
data
# Out:
# [<li class="o-listicle__item">
#  <article class="m-statement m-statement--is-medium m-statement--false">
#  <div class="m-statement__author">
#  <div class="m-statement__avatar">
#  <div class="m-statement__image">
#  <div class="c-image" style="padding-top: 119.27710843373494%;">
#  <img class="c-image__thumb" height="99" src="https://static.politifact.com/CACHE/images/politifact/mugs/new_djt_mugshot/80bd15ec0d50cf908299031c9790109e.jpg" width="83"/>
#  <picture>
#  <img class="c-image__original" height="178" src="https://static.politifact.com/CACHE/images/politifact/mugs/new_djt_mugshot/c1c32c5a2e0a94447f75d2e6dfe5573d.jpg" width="166"/>
#  </picture>
#  </div>
#  </div>
#  </div>
#  <div class="m-statement__meta">
#  <a class="m-statement__name" href="/personalities/donald-trump/" title="Donald Trump">
#                      Donald Trump
#                    </a>
#  <div class="m-statement__desc">
#                      stated on May 18, 2026 in remarks at the White House:
# ...

# %%
data[0]
# Out:
# <li class="o-listicle__item">
# <article class="m-statement m-statement--is-medium m-statement--false">
# <div class="m-statement__author">
# <div class="m-statement__avatar">
# <div class="m-statement__image">
# <div class="c-image" style="padding-top: 119.27710843373494%;">
# <img class="c-image__thumb" height="99" src="https://static.politifact.com/CACHE/images/politifact/mugs/new_djt_mugshot/80bd15ec0d50cf908299031c9790109e.jpg" width="83"/>
# <picture>
# <img class="c-image__original" height="178" src="https://static.politifact.com/CACHE/images/politifact/mugs/new_djt_mugshot/c1c32c5a2e0a94447f75d2e6dfe5573d.jpg" width="166"/>
# </picture>
# </div>
# </div>
# </div>
# <div class="m-statement__meta">
# <a class="m-statement__name" href="/personalities/donald-trump/" title="Donald Trump">
#                     Donald Trump
#                   </a>
# <div class="m-statement__desc">
#                     stated on May 18, 2026 in remarks at the White House:
# ...

# %%
len(data)
# Out:
# 30

# %%
source=[]
print(data[0].find('div',class_="m-statement__meta").find('a').text.strip())
# Out:
# Donald Trump

# %%
source=[]
for i in data:
    source.append(i.find('div',class_='m-statement__meta').find('a').text.strip())
print(source)
# Out:
# ['Donald Trump', 'Social Media', 'X posts', 'X posts', 'Kathy Castor', 'Vivek Ramaswamy', 'TikTok posts', 'Christine Quinn', 'Nicholas Langworthy', 'Donald Trump', 'Byron Donalds', 'Marcy Kaptur', 'Liz Krueger', 'X posts', 'Donald Trump', 'Sam Sutton', 'Fentrice Driskell', 'Instagram posts', 'Bernie Sanders', 'Tim Scott', 'Pine Tree Results PAC', 'Social Media', 'Donald Trump', 'Ron DeSantis', 'Social Media', 'Jay Collins', 'Robert F. Kennedy Jr.', 'Joe Rogan', 'X posts', 'Chris Wright']

# %%
statement=[]
for i in data:
    statement.append(i.find('div',class_='m-statement__quote').text.strip())
print(statement)
# Out:
# ['"There\'s been numerous other occasions over the years” when the federal government created a reserve similar to a new $1.776 billion anti-weaponization settlement fund.', '“San Diego mosque shooters identified as trans couple.”', 'Video shows U.S. Rep. Byron Donalds saying, “Insider trading should absolutely be allowed for members of Congress.”', 'An American passenger on the cruise ship involved in the hantavirus outbreak is a "crisis actor."', '“Florida is the only state in the nation kicking children off their affordable health coverage.”', 'In 2020, “Amy Acton called off Ohio’s election at the last minute.”', 'Imágenes muestran a personas “infectadas con Hantavirus”.', '“Today, there are more children sleeping in New York City’s homeless shelters than there are seats in Yankee Stadium.”', '“The average IRS tax refund is up 11% compared to last year.”', 'Gasoline prices have “come down very substantially today.”', 'Congress passed the 1965 Voting Rights Act because “the Democra
# ...

# %%
date=[]
for i in data:
    date.append(i.find('footer',class_='m-statement__footer').text.split(' • ')[-1].strip())
print(date)
# Out:
# ['May 20, 2026', 'May 20, 2026', 'May 15, 2026', 'May 14, 2026', 'May 14, 2026', 'May 13, 2026', 'May 13, 2026', 'May 11, 2026', 'May 11, 2026', 'May 8, 2026', 'May 8, 2026', 'May 8, 2026', 'May 7, 2026', 'May 7, 2026', 'May 6, 2026', 'May 5, 2026', 'May 1, 2026', 'April 30, 2026', 'April 30, 2026', 'April 29, 2026', 'April 29, 2026', 'April 29, 2026', 'April 29, 2026', 'April 29, 2026', 'April 28, 2026', 'April 23, 2026', 'April 23, 2026', 'April 22, 2026', 'April 22, 2026', 'April 22, 2026']

# %%
links=[]
root='https://www.politifact.com'
for i in data:
    d=i.find('div',class_='m-statement__quote').find('a')['href'].strip()
    links.append(root+d)
print(links)
# Out:
# ['https://www.politifact.com/factchecks/2026/may/20/donald-trump/legal-settlement-fund-weaponization-justice-jan-6/', 'https://www.politifact.com/factchecks/2026/may/20/social-media/no-evidence-san-diego-mosque-suspects-trans/', 'https://www.politifact.com/factchecks/2026/may/15/tweets/byron-donalds-florida-insider-trading/', 'https://www.politifact.com/factchecks/2026/may/14/tweets/hantavirus-quarantine-crisis-actor-rosmarin/', 'https://www.politifact.com/factchecks/2026/may/14/kathy-castor/kid-care-florida-desantis-health-insurance/', 'https://www.politifact.com/factchecks/2026/may/13/vivek-ramaswamy/Amy-Acton-Ohio-2020-covid-primary-senate/', 'https://www.politifact.com/factchecks/2026/may/13/tiktok-posts/hantavirus-infectados-imagenes-crucero/', 'https://www.politifact.com/factchecks/2026/may/11/christine-quinn/new-york-city-homeless-children-yankee-stadium/', 'https://www.politifact.com/factchecks/2026/may/11/nicholas-langworthy/tax-refunds-11-percent-reduction-irs/', 'https://w
# ...

# %%
import pandas as pd

df=pd.DataFrame({'Statements':statement,
                'Source':source,
                'Links':links,
                'Date':date})
df
# Out:
#                                            Statements  \
# 0   "There's been numerous other occasions over th...
# 1   “San Diego mosque shooters identified as trans...
# 2   Video shows U.S. Rep. Byron Donalds saying, “I...
# 3   An American passenger on the cruise ship invol...
# 4   “Florida is the only state in the nation kicki...
# 5   In 2020, “Amy Acton called off Ohio’s election...
# 6   Imágenes muestran a personas “infectadas con H...
# 7   “Today, there are more children sleeping in Ne...
# 8   “The average IRS tax refund is up 11% compared...
# 9   Gasoline prices have “come down very substanti...
# 10  Congress passed the 1965 Voting Rights Act bec...
# 11  Republicans “want you to pay $1 Billion for a ...
# 12  Proposed data centers in New York state would ...
# 13  “California only has ‘enough’ oil and gas supp...
# 14                   “Consumer confidence is way up."
# 15  From January 2025 to January 2026, “hate crime...
# ...

# %%
df.to_excel('politifacts.xlsx')

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(open('politifact.html','r',encoding='utf-8'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Fact-checks | PolitiFact
#   </title>
#   <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="description"/>
#   <meta content="all" name="robots"/>
#   <meta content="PolitiFact" name="publisher"/>
#   <meta content="PolitiFact" name="twitter:username"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="PolitiFact" name="twitter:site"/>
#   <meta content="" name="twitter:url"/>
#   <meta content="" name="twitter:title"/>
#   <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="twitter:description"/>
# ...

# %% [markdown]
# # For multiple pages

# %%
import requests
from bs4 import BeautifulSoup
upperframe=[]
for page in range(1,5):
    url = 'https://www.politifact.com/factchecks/'
    result=requests.get(url)
    content=result.text
    soup=BeautifulSoup(content,'html.parser')

    frame=[]
    data=soup.find_all('li',class_='o-listicle__item')
    for i in data:
         source=i.find('div',class_='m-statement__meta').find('a').text.strip()
         statement=i.find('div',class_='m-statement__quote').text.strip()
         links=i.find('div',class_='m-statement__quote').find('a')['href'].strip()
         date=i.find('footer',class_='m-statement__footer').text.split(' • ')[-1].strip()
         frame.append((statement,source,date,links))
    upperframe.extend(frame)
    
print(len(upperframe))
# Out:
# 120

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(open('top250.html','r',encoding='utf-8'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
#
#     var ue_err_chan = 'jserr';
# ...

# %%
movie=soup.find_all('td',class_='titleColumn')
len(movie)
# Out:
# 250

# %%
title=[]
for i in movie:
    title.append(i.find('a').text.strip())
print(title)
# Out:
# ['The Shawshank Redemption', 'The Godfather', 'The Dark Knight', 'The Godfather Part II', '12 Angry Men', "Schindler's List", 'The Lord of the Rings: The Return of the King', 'Pulp Fiction', 'The Lord of the Rings: The Fellowship of the Ring', 'The Good, the Bad and the Ugly', 'Spider-Man: Across the Spider-Verse', 'Forrest Gump', 'Fight Club', 'The Lord of the Rings: The Two Towers', 'Inception', 'Star Wars: Episode V - The Empire Strikes Back', 'The Matrix', 'Goodfellas', "One Flew Over the Cuckoo's Nest", 'Se7en', "It's a Wonderful Life", 'Seven Samurai', 'The Silence of the Lambs', 'Saving Private Ryan', 'City of God', 'Interstellar', 'Life Is Beautiful', 'The Green Mile', 'Star Wars: Episode IV - A New Hope', 'Terminator 2: Judgment Day', 'Back to the Future', 'Spirited Away', 'The Pianist', 'Psycho', 'Parasite', 'Léon: The Professional', 'The Lion King', 'Gladiator', 'American History X', 'The Departed', 'Whiplash', 'The Prestige', 'The Usual Suspects', 'Casablanca', 'Grave of 
# ...

# %%
year=[]
for i in movie:
    year.append(i.find('span',class_='secondaryInfo').text[1:-1].strip())
print(year)
# Out:
# ['1994', '1972', '2008', '1974', '1957', '1993', '2003', '1994', '2001', '1966', '2023', '1994', '1999', '2002', '2010', '1980', '1999', '1990', '1975', '1995', '1946', '1954', '1991', '1998', '2002', '2014', '1997', '1999', '1977', '1991', '1985', '2001', '2002', '1960', '2019', '1994', '1994', '2000', '1998', '2006', '2014', '2006', '1995', '1942', '1988', '1962', '2011', '1936', '1968', '1988', '1954', '1979', '1931', '1979', '2000', '2012', '1981', '2008', '2006', '1950', '1957', '2018', '1980', '1940', '1957', '2018', '1986', '1999', '2012', '1964', '2009', '2003', '2017', '1984', '1995', '1995', '1981', '2019', '2019', '1997', '1997', '1984', '2016', '2009', '1952', '1963', '2000', '2018', '2010', '1983', '1985', '2004', '1968', '2012', '1992', '1962', '1941', '1931', '1952', '1959', '1960', '1958', '2001', '1944', '1971', '1987', '2020', '1983', '2010', '1995', '2009', '1962', '1973', '2011', '1927', '1997', '1988', '1989', '2000', '1976', '1948', '2007', '2019', '2016', '2004
# ...

# %%
rating=[]
for i in soup.find_all('td',class_='ratingColumn imdbRating'):
    rating.append(i.text.strip())
print(rating)
# Out:
# ['9.2', '9.2', '9.0', '9.0', '9.0', '8.9', '8.9', '8.8', '8.8', '8.8', '8.8', '8.8', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.
# ...

# %%
df=pd.DataFrame({'Title':title,'Year':year,'rating':rating})
df
# Out:
#                         Title  Year rating
# 0    The Shawshank Redemption  1994    9.2
# 1               The Godfather  1972    9.2
# 2             The Dark Knight  2008    9.0
# 3       The Godfather Part II  1974    9.0
# 4                12 Angry Men  1957    9.0
# ..                        ...   ...    ...
# 245                  The Help  2011    8.0
# 246             Life of Brian  1979    8.0
# 247            The Iron Giant  1999    8.0
# 248                   Aladdin  1992    8.0
# 249        Dances with Wolves  1990    8.0
#
# [250 rows x 3 columns]
